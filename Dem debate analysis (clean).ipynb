# %% [markdown]
# # Playing around with text analysis

# %% [markdown]
# Playing around with loops, regex, basic pandas/numpy functions, tokenization

# %%
#download June 26 dem debate youtube transcript
text = open("June 26 Dem debate full text youtube2.txt").read()

text
# Out:
# 'LESTER HOLT:\nGood evening, everyone. I\'m Lester Holt, and welcome to the first Democratic debate to the 2020 race for president.\nSAVANNAH GUTHRIE:\nHi, I\'m Savannah Guthrie. And tonight, it\'s our first chance to see these candidates go head to head on stage together.\nWe\'ll be joined in our questioning time by our colleagues, Jose Diaz-Balart, Chuck Todd, and Rachel Maddow.\nHOLT:\nVoters are trying to nail down where the candidates stand on the issues, what sets them apart, and which of these presidential hopefuls has what it takes.\nGUTHRIE:\nWell, now it\'s time to find out.\nANNOUNCER:\nTonight, round one. New Jersey Senator Cory Booker. Former Housing Secretary Julian Castro. New York City Mayor Bill De Blasio. Former Maryland Congressman John Delaney. Hawaii Congresswoman Tulsi Gabbard. Washington Governor Jay Inslee. Minnesota Senator Amy Klobuchar. Former Texas Congressman Beto O\'Rourke. Ohio Congressman Tim Ryan. And Massachusetts Senator Elizabeth Warren.\nFrom NBC News, "Decision 2020," the Democratic candidates debate, live from the Adrienne Arsht Performing Arts Center in Miami, Florida.\nHOLT:\nAnd good evening again, everyone. Welcome to the candidates and to our audience here in Miami here in the Arts Center and all across the country. Tonight we\'re going to take on many of the most pressing issues of the moment, including immigration, the situation unfolding at our border, and the treatment of migrant children.\nGUTHRIE:\nAnd we\'re going to talk about the tensions with Iran, climate change, and of course, we\'ll talk about the economy, those kitchen table issues so many Americans face every day.\nDIAZ-BALART:\nAnd some quick rules of the road. Before we begin, 20 candidates qualified for this first debate. We\'ll hear from 10 tonight and 10 more tomorrow. The breakdown for each was selected at random. The candidates will have 60 seconds to answer and 30 seconds for any follow-ups.\nHOLT:\nBecause of this large field, not every person will be able to comment on every topic, but over the course of the next two hours, we will hear from everyone. We\'d also like to ask the audience to keep the reactions to a minimum. We are not going to be shy about making sure the candidates stick to time tonight.\nGUTHRIE:\nAll right. So with that business out of the way, we want to get to it. And we\'ll start this evening with Senator Elizabeth Warren.\nSenator, good evening to you.\nELIZABETH WARREN:\nThank you. Good to be here.\nGUTHRIE:\nYou have many plans -- free college, free child care, government health care, cancellation of student debt, new taxes, new regulations, the breakup of major corporations. But this comes at a time when 71 percent of Americans say the economy is doing well, including 60 percent of Democrats. What do you say to those who worry this kind of significant change could be risky to the economy?\nWARREN:\nSo I think of it this way. Who is this economy really working for? It\'s doing great for a thinner and thinner slice at the top. It\'s doing great for giant drug companies. It\'s just not doing great for people who are trying to get a prescription filled.\nIt\'s doing great for people who want to invest in private prisons, just not for the African-Americans and Latinx whose families are torn apart, whose lives are destroyed, and whose communities are ruined.\nIt\'s doing great for giant oil companies that want to drill everywhere, just not for the rest of us who are watching climate change bear down upon us.\nWhen you\'ve got a government, when you\'ve got an economy that does great for those with money and isn\'t doing great for everyone else, that is corruption, pure and simple. We need to call it out. We need to attack it head on. And we need to make structural change in our government, in our economy, and in our country.\nGUTHRIE:\nSenator Klobuchar, you\'ve called programs like free college something you might do if you were, quote, "a magic genie." To be blunt, are the government prog ...

# %%
#As you can see there is a line break '\n'. Let's remove these
text = text.replace("\n"," ")

# %%
#import our tools
import re
import numpy as np
import pandas as pd
"""
Using regex's flexible rules, looks for capitalised named, regardless of whether
the name is hypenated (Diaz-Balart), or is a  single word (Warren) or double word (Elizabeth Warren),
or more (Bill De Blasio), or includes an special symbol (O'Rourke) 
- although this last filter doesn't seem to work
"""
pattern = re.compile(r"[\(]?([A-Z]?\w+\s?[A-Z]?\w+\s?-?'?[A-Z]\w+)[\)]?:")
matches = pattern.finditer(text)

# %%
#Set empty arrays to the name of the speaker and the text position when they start talking

name = []
pos = []
posnum = []
for match in matches:
    name.append(match.group(1))
    pos.append(match.span())
    start,end = match.span()
    
pos = pd.DataFrame(pos)
name = pd.DataFrame(name)
text[pos[1][0]:pos[0][1]]
text[pos[1][1]:pos[0][2]]
pos[1][2]
pos[0][3]
# Out:
# 536

# %%
pos.head()
# Out:
#      0    1
# 0    0   12
# 1  129  146
# 2  375  380
# 3  536  544
# 4  578  588

# %%
""" This part is not pretty. Using the previous positions, a new array will
identifies the text position where the speaker starts/stops speaking 
"""
pos['speech_loc_start'] = pos[1]+1
pos['speech_loc_end'] = pos[0].shift(-1)+1
pos['speech_loc_end'].iloc[-1] = len(text)
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
pos.head()
# Out:
#      0    1  speech_loc_start  speech_loc_end
# 0    0   12                13           130.0
# 1  129  146               147           376.0
# 2  375  380               381           537.0
# 3  536  544               545           579.0
# 4  578  588               589          1109.0

# %%
speech = []

#Using the positions, saves speeches in the order spoken to the speech df
for index, row in pos.iterrows():
     speech.append(text[int(row['speech_loc_start']):int(row['speech_loc_end'])])
speech = pd.DataFrame(speech)

# %%
"""Create new df called transcript
The index indicates order of the conversation, name indicates speaker, 
speech indicates words spoken during that segemment
"""
speech.columns = ['speech']
name.columns = ['name']
transcript = name['name']
transcript = pd.concat([name,speech],axis=1)

transcript.head()
# Out:
#                name                                             speech
# 0       LESTER HOLT  Good evening, everyone. I'm Lester Holt, and w...
# 1  SAVANNAH GUTHRIE  Hi, I'm Savannah Guthrie. And tonight, it's ou...
# 2              HOLT  Voters are trying to nail down where the candi...
# 3           GUTHRIE                 Well, now it's time to find out. A
# 4         ANNOUNCER  Tonight, round one. New Jersey Senator Cory Bo...

# %%
# Let's take a look at who spoke the most
speak_count = transcript['name'].value_counts()
speak_count
# Out:
# TODD                72
# HOLT                40
# MADDOW              36
# GUTHRIE             31
# DELANEY             27
# DIAZ-BALART         26
# ROURKE              25
# CASTRO              21
# RYAN                21
# BOOKER              17
# WARREN              15
# GABBARD             14
# KLOBUCHAR           13
# DE BLASIO           12
# INSLEE               8
# UNKNOWN              6
# ELIZABETH WARREN     1
# CORY BOOKER          1
# AMY KLOBUCHAR        1
# BILL DE BLASIO       1
# ANNOUNCER            1
# BETO O'ROURKE        1
# TULSI GABBARD        1
# JAY INSLEE           1
# LESTER HOLT          1
# JULIÁN CASTRO        1
# JOHN DELANEY         1
# SAVANNAH GUTHRIE     1
# Name: name, dtype: int64

# %%
"""
The way the transcript is written, the first time a candidate is introduces, their full names are used;
last names are use subsequently. Let's clean this up
"""
speak_count = pd.DataFrame(speak_count.reset_index())
speak_count.columns = ['name','count']

# %%
#cleans up names by setting all names to last name
transcript['name_clean'] = transcript['name']

for index, row in transcript.iterrows():
    if len(transcript['name'][index].split()) == 2:
        transcript['name_clean'].iloc[index] = transcript['name'].iloc[index].split()[1]
    if len(transcript['name'][index].split()) == 3:
        transcript['name_clean'].iloc[index] = transcript['name'].iloc[index].split()[1:2]

# %%
cleaned = pd.Series(transcript['name_clean'])
#cleaned.value_counts()

# %%
for name in transcript['name']:
    print(name.split())
# Out:
# ['LESTER', 'HOLT']
# ['SAVANNAH', 'GUTHRIE']
# ['HOLT']
# ['GUTHRIE']
# ['ANNOUNCER']
# ['HOLT']
# ['GUTHRIE']
# ['DIAZ-BALART']
# ['HOLT']
# ['GUTHRIE']
# ['ELIZABETH', 'WARREN']
# ['GUTHRIE']
# ['WARREN']
# ['GUTHRIE']
# ['AMY', 'KLOBUCHAR']
# ['GUTHRIE']
# ['BETO', "O'ROURKE"]
# ['ROURKE']
# ['GUTHRIE']
# ['ROURKE']
# ['GUTHRIE']
# ['ROURKE']
# ['GUTHRIE']
# ['ROURKE']
# ['GUTHRIE']
# ['ROURKE']
# ['GUTHRIE']
# ['CORY', 'BOOKER']
# ['GUTHRIE']
# ['BOOKER']
# ['GUTHRIE']
# ['BOOKER']
# ['GUTHRIE']
# ['GUTHRIE']
# ['WARREN']
# ['GUTHRIE']
# ['HOLT']
# ['JULIÁN', 'CASTRO']
# ['HOLT']
# ['TULSI', 'GABBARD']
# ['DIAZ-BALART']
# ['BILL', 'DE', 'BLASIO']
# ['DIAZ-BALART']
# ['JOHN', 'DELANEY']
# ['DIAZ-BALART']
# ['JAY', 'INSLEE']
# ['DIAZ-BALART']
# ['RYAN']
# ['DIAZ-BALART']
# ['RYAN']
# ['DIAZ-BALART']
# ['WARREN']
# ['DIAZ-BALART']
# ['WARREN']
# ['HOLT']
# ['KLOBUCHAR']
# ['HOLT']
# ['WARREN']
# ['HOLT']
# ['ROURKE']
# ['HOLT']
# ['ROURKE']
# ['HOLT']
# ['ROURKE']
# ['DE', 'BLASIO']
# ['ROURKE']
# ['DE', 'BLASIO']
# ['ROURKE']
# ['DE', 'BLASIO']
# ['ROURKE']
# ['DE', 'BLASIO']
# ['DELANEY']
# ['HOLT']
# ['GABBARD']
# ['HOLT']
# ['GABBARD']
# ['HOLT']
# ['HOLT']
# ['BOOKER']
# ['HOLT']
# ['BOOKER']
# ['HOLT']
# ['HOLT']
# ['WARREN']
# ['WARREN']
# ['INSLEE']
# ['HOLT']
# ['HOLT']
# ['UNKNOWN']
# ['HOLT']
# ['KLOBUCHAR']
# ['HOLT']
# ['CASTRO']
# ['HOLT']
# ['WARREN']
# ['HOLT']
# ['WARREN']
# ['HOLT']
# ['DIAZ-BALART']
# ['BOOKER']
# ['DIAZ-BALART']
# ['ROURKE']
# ['HOLT']
# ['DIAZ-BALART']
# ['CASTRO']
# ['DIAZ-BALART']
# ['CASTRO']
# ['DIAZ-BALART']
# ['BOOKER']
# ['CASTRO']
# ['UNKNOWN']
# ['UNKNOWN']
# ['CASTRO']
# ['DIAZ-BALART']
# ['BOOKER']
# ['DE', 'BLASIO']
# ['DIAZ-BALART']
# ['DE', 'BLASIO']
# ['DIAZ-BALART']
# ['ROURKE']
# ['CASTRO']
# ['ROURKE']
# ['DIAZ-BALART']
# ['ROURKE']
# ['DIAZ-BALART']
# ['CASTRO']
# ['CASTRO']
# ['DIAZ-BALART']
# ['CASTRO']
# ['ROURKE']
# ['CASTRO']
# ['ROURKE']
# ['CASTRO']
# ['ROURKE']
# ['CASTRO']
# ['ROURKE']
# ['CASTRO']
# ['ROURKE']
# ['CASTRO']
# ['DIAZ-BALART']
# ['DELANEY']
# ['DIAZ-BALART']
# ['DELANEY']
# ['GUTHRIE']
# ['DELANEY']
# ['GUTHRIE']
# ['KLOBUCHAR']
# ['GUTHRIE']
# ['KLOBUCHAR']
# ['GUTHRIE']
# ['KLOBUCHAR']
# ['GUTHRIE']
# ['RYAN']
# ['GUTHRIE']
# ['BOOKER']
# ['GUTHRIE']
# ['INSLEE']
# ['GUTHRIE']
# ['INSLEE']
# ['HOLT']
# ['DELANEY']
# ['HOLT']
# ['BOOKER']
# ['HOLT']
# ['UNKNOWN']
# ['KLOBUCHAR']
# ['HOLT']
# ['GABBARD']
# ['HOLT']
# ['GABBARD']
# ['DE', 'BLASIO']
# ['GUTHRIE']
# ['HOLT']
# ['GUTHRIE']
# ['DIAZ-BALART']
# ['MADDOW']
# ['TODD']
# ['MADDOW']
# ['TODD']
# ['MADDOW']
# ['TODD']
# ['TODD']
# ['UNKNOWN']
# ['TODD']
# ['MADDOW']
# ['TODD']
# ['MADDOW']
# ['TODD']
# ['TODD']
# ['MADDOW']
# ['TODD']
# ['TODD']
# ['MADDOW']
# ['TODD']
# ['WARREN']
# ['TODD']
# ['WARREN']
# ['TODD']
# ['WARREN']
# ['TODD']
# ['BOOKER']
# ['TODD']
# ['MADDOW']
# ['CASTRO']
# ['TODD']
# ['RYAN']
# ['MADDOW']
# ['RYAN']
# ['MADDOW']
# ['TODD']
# ['ROURKE']
# ['TODD']
# ['KLOBUCHAR']
# ['TODD']
# ['KLOBUCHAR']
# ['TODD']
# ['MADDOW']
# ['TODD']
# ['MADDOW']
# ['BOOKER']
# ['MADDOW']
# ['DELANEY']
# ['MADDOW']
# ['DELANEY']
# ['MADDOW']
# ['DE', 'BLASIO']
# ['MADDOW']
# ['TODD']
# ['WARREN']
# ['TODD']
# ['WARREN']
# ['TODD']
# ['DELANEY']
# ['TODD']
# ['DELANEY']
# ['TODD']
# ['TODD']
# ['BOOKER']
# ['TODD']
# ['MADDOW']
# ['TODD']
# ['MADDOW']
# ['INSLEE']
# ['MADDOW']
# ['INSLEE']
# ['MADDOW']
# ['TODD']
# ['ROURKE']
# ['TODD']
# ['CASTRO']
# ['TODD']
# ['CASTRO']
# ['TODD']
# ['RYAN']
# ['TODD']
# ['RYAN']
# ['TODD']
# ['CASTRO']
# ['RYAN']
# ['TODD']
# ['RYAN']
# ['TODD']
# ['UNKNOWN']
# ['TODD']
# ['DELANEY']
# ['TODD']
# ['DELANEY']
# ['TODD']
# ['DELANEY']
# ['TODD']
# ['DELANEY']
# ['TODD']
# ['DELANEY']
# ['TODD']
# ['GABBARD']
# ['BOOKER']
# ['TODD']
# ['BOOKER']
# ['TODD']
# ['BOOKER']
# ['MADDOW']
# ['KLOBUCHAR']
# ['MADDOW']
# ['KLOBUCHAR']
# ['MADDOW']
# ['CASTRO']
# ['MADDOW']
# ['TODD']
# ['HOLT']
# ['ROURKE']
# ['DE', 'BLASIO']
# ['MADDOW']
# ['DE', 'BLASIO']
# ['MADDOW']
# ['RYAN']
# ['MADDOW']
# ['GABBARD']
# ['TODD']
# ['RYAN']
# ['TODD']
# ['RYAN']
# ['GABBARD']
# ['RYAN']
# ['GABBARD']
# ['RYAN']
# ['GABBARD']
# ['RYAN']
# ['GABBARD']
# ['RYAN']
# ['TODD']
# ['RYAN']
# ['GABBARD']
# ['TODD']
# ['DELANEY']
# ['TODD']
# ['DELANEY']
# ['TODD']
# ['DELANEY']
# ['TODD']
# ['INSLEE']
# ['TODD']
# ['GABBARD']
# ['TODD']
# ['GABBARD']
# ['TODD']
# ['KLOBUCHAR']
# ['TODD']
# ['ROURKE']
# ['TODD']
# ['INSLEE']
# ['TODD']
# ['BOOKER']
# ['TODD']
# ['CASTRO']
# ['TODD']
# ['RYAN']
# ['TODD']
# ['DE', 'BLASIO']
# ['TODD']
# ['ROURKE']
# ['TODD']
# ['TODD']
# ['MADDOW']
# ['DELANEY']
# ['MADDOW']
# ['DELANEY']
# ['MADDOW']
# ['DELANEY']
# ['MADDOW']
# ['DELANEY']
# ['MADDOW']
# ['DELANEY']
# ['MADDOW']
# ['TODD']
# ['KLOBUCHAR']
# ['TODD']
# ['HOLT']
# ['DELANEY']
# ['HOLT']
# ['DELANEY']
# ['HOLT']
# ['DELANEY']
# ['HOLT']
# ['DELANEY']
# ['HOLT']
# ['DELANEY']
# ['HOLT']
# ['GUTHRIE']
# ['DE', 'BLASIO']
# ['GUTHRIE']
# ['DIAZ-BALART']
# ['INSLEE']
# ['DIAZ-BALART']
# ['TODD']
# ['RYAN']
# ['TODD']
# ['RYAN']
# ['TODD']
# ['RYAN']
# ['MADDOW']
# ['GABBARD']
# ['MADDOW']
# ['HOLT']
# ['CASTRO']
# ['GUTHRIE']
# ['KLOBUCHAR']
# ['GUTHRIE']
# ['DIAZ-BALART']
# ['BOOKER']
# ['DIAZ-BALART']
# ['TODD']
# ['TODD']
# ['MADDOW']
# ['WARREN']
# ['GUTHRIE']
# ['HOLT']

# %%
type(transcript['name'])
# Out:
# pandas.core.series.Series

# %%
transcript['name'].value_counts()
# Out:
# TODD                72
# HOLT                40
# MADDOW              36
# GUTHRIE             31
# DELANEY             27
# DIAZ-BALART         26
# ROURKE              25
# CASTRO              21
# RYAN                21
# BOOKER              17
# WARREN              15
# GABBARD             14
# KLOBUCHAR           13
# DE BLASIO           12
# INSLEE               8
# UNKNOWN              6
# ELIZABETH WARREN     1
# CORY BOOKER          1
# AMY KLOBUCHAR        1
# BILL DE BLASIO       1
# ANNOUNCER            1
# BETO O'ROURKE        1
# TULSI GABBARD        1
# JAY INSLEE           1
# LESTER HOLT          1
# JULIÁN CASTRO        1
# JOHN DELANEY         1
# SAVANNAH GUTHRIE     1
# Name: name, dtype: int64

# %%
type(transcript['name'])
# Out:
# pandas.core.series.Series

# %%
transcript['name_clean'].apply(tuple).value_counts()
# Out:
# (T, O, D, D)                         72
# (H, O, L, T)                         41
# (M, A, D, D, O, W)                   36
# (G, U, T, H, R, I, E)                32
# (D, E, L, A, N, E, Y)                28
# (D, I, A, Z, -, B, A, L, A, R, T)    26
# (R, O, U, R, K, E)                   25
# (C, A, S, T, R, O)                   22
# (R, Y, A, N)                         21
# (B, O, O, K, E, R)                   18
# (W, A, R, R, E, N)                   16
# (G, A, B, B, A, R, D)                15
# (K, L, O, B, U, C, H, A, R)          14
# (B, L, A, S, I, O)                   12
# (I, N, S, L, E, E)                    9
# (U, N, K, N, O, W, N)                 6
# (A, N, N, O, U, N, C, E, R)           1
# (DE,)                                 1
# (O, ', R, O, U, R, K, E)              1
# Name: name_clean, dtype: int64

# %%
transcript[transcript['name_clean']=="O'ROURKE"]
# Out:
#              name                                             speech  \
# 16  BETO O'ROURKE  This economy has got to work for everyone. And...
#
#    name_clean
# 16   O'ROURKE

# %%
transcript['name_clean'] = transcript['name_clean'].replace("O'ROURKE","ROURKE")
candidate = ['ROURKE','CASTRO','RYAN','BOOKER','WARREN','GABBARD','KLOBUCHAR','BLASIO','INSLEE']

# %%
transcript[transcript['name_clean'] == 'WARREN']['speech']
# Out:
# 10                         Thank you. Good to be here. G
# 12     So I think of it this way. Who is this economy...
# 34     So the way I understand this, it's there is wa...
# 51     So we've had an industrial policy in the Unite...
# 53                                     We can do this. H
# 57     So, yes. I'm with Bernie on Medicare for all. ...
# 83     ... point, though, and that is that the insura...
# 84       It's time for us to make families come first. I
# 94     I would make certain that every woman has acce...
# 96     We now have an America where most people suppo...
# 194    So, in this period of time that I have been ru...
# 196    What I think we need to do is we need to treat...
# 198                 We need to fight for our children. T
# 228                                              I do. T
# 230    I do. We are democracy. And the way a democrac...
# 393    Thank you. It's a great honor to be here. Neve...
# Name: speech, dtype: object

# %%
"""for name in candidate:
    speech_dict = [transcript[transcript['name_clean'] == name]['speech']]
    print(speech_dict)
"""
# Out:
# "for name in candidate:\n    speech_dict = [transcript[transcript['name_clean'] == name]['speech']]\n    print(speech_dict)\n"

# %%
candidate = pd.DataFrame(candidate)
candidate.columns = ['Candidate Name']
candidate
' '.join(candidate['Candidate Name'].tolist())
# Out:
# 'ROURKE CASTRO RYAN BOOKER WARREN GABBARD KLOBUCHAR BLASIO INSLEE'

# %%
'''
for name in candidate['Candidate Name']:
    speech_dict = [transcript[transcript['name_clean'] == name]['speech']]
    ' '.join([transcript[transcript['name_clean'] == name]['speech']].tolist())
'''
# Out:
# "\nfor name in candidate['Candidate Name']:\n    speech_dict = [transcript[transcript['name_clean'] == name]['speech']]\n    ' '.join([transcript[transcript['name_clean'] == name]['speech']].tolist())\n"

# %%
warren = transcript[transcript['name_clean'] == 'WARREN']

# %%
def speech_concat(name):
    
    speech = ''
    
    for rows in transcript[transcript['name_clean'] == name]['speech']:
        speech = speech + rows 

    return speech

# %%
candidate['Speech'] = candidate['Candidate Name'].apply(speech_concat)

# %%
candidate
# Out:
#   Candidate Name                                             Speech
# 0         ROURKE  This economy has got to work for everyone. And...
# 1         CASTRO  Thank you very much for that question, Lester....
# 2           RYAN  Yes, I believe you can, but, first, let's say ...
# 3         BOOKER  I don't think I disagree. I think we have a se...
# 4         WARREN  Thank you. Good to be here. GSo I think of it ...
# 5        GABBARD  First of all, let's recognize the situation we...
# 6      KLOBUCHAR  Well, first, the economy. We know that not eve...
# 7         BLASIO  Wait, wait, wait. Congressman O'Rourke, Congre...
# 8         INSLEE  Well, I'm a little bit surprised. I think plan...

# %%
def speech_analysis(name):
    speech = candidate[candidate['Candidate Name']== name]['Speech'].item().split(' ')
    print('Word spoken: ', len(speech))

    unique_words = set(speech)
    print('Unique words: ', len(unique_words))

# %%
for names in candidate['Candidate Name']:
    print(names)
    speech_analysis(names)
    print('')
# Out:
# ROURKE
# Word spoken:  1585
# Unique words:  695
#
# CASTRO
# Word spoken:  1646
# Unique words:  689
#
# RYAN
# Word spoken:  1406
# Unique words:  584
#
# BOOKER
# Word spoken:  2222
# Unique words:  785
#
# WARREN
# Word spoken:  1580
# Unique words:  619
#
# GABBARD
# Word spoken:  1262
# Unique words:  518
#
# KLOBUCHAR
# Word spoken:  1628
# Unique words:  646
#
# BLASIO
# Word spoken:  978
# Unique words:  450
#
# INSLEE
# Word spoken:  886
# Unique words:  373

# %%
Rourke = candidate[candidate['Candidate Name']== 'ROURKE']['Speech'].item().split(' ')
unique_words = set(Rourke)

word_histogram = dict.fromkeys(unique_words, 0)
for word in Rourke:
    word_histogram[word] = word_histogram[word]+ 1
    
df_histo = unique_words
for word in Rourke:
    df_hist[word] = word_histogram[word]+ 1

# %%
word_histogram
# Out:
# {'': 24,
#  '$2': 1,
#  '$5': 1,
#  '(CROSSTALK)': 1,
#  '--': 5,
#  '10': 1,
#  '2': 1,
#  '2,000': 1,
#  '2.3': 1,
#  '2016,': 1,
#  '254': 1,
#  '27': 1,
#  '28': 1,
#  '40.': 1,
#  'A': 2,
#  'Act': 1,
#  'America': 1,
#  'America,': 1,
#  'American': 1,
#  'Americans': 1,
#  'And': 8,
#  'As': 2,
#  'Bree.': 1,
#  'But': 3,
#  'C...': 1,
#  'CAnd': 1,
#  'CBut': 1,
#  "CHere's": 1,
#  'CIf': 1,
#  'CWe': 1,
#  'Celsius,': 1,
#  'Central': 1,
#  'Congress,': 1,
#  'D...': 2,
#  'DLet': 1,
#  'DOur': 1,
#  "DThat's": 1,
#  'DTonight': 1,
#  'DWe': 1,
#  'Democrats': 1,
#  'Douglas': 1,
#  'Dreamers': 1,
#  'Fe': 1,
#  'Florida,': 1,
#  'For': 1,
#  'G...': 2,
#  'GI': 1,
#  'GMy': 1,
#  "GThat's": 1,
#  'HNo.': 1,
#  'HWe': 2,
#  'Hart,': 1,
#  "He's": 2,
#  'Her': 1,
#  'Houston,': 1,
#  'I': 12,
#  "I'll": 1,
#  "I'm": 1,
#  'If': 2,
#  'In': 4,
#  'Iowa.': 1,
#  'Iran': 1,
#  "It's": 1,
#  'Junction': 1,
#  'Junction,': 1,
#  'Korea': 1,
#  'Laredo,': 1,
#  'Many': 1,
#  'Marcel,': 1,
#  'Marjory': 1,
#  'Medicare.': 3,
#  'Miami,': 1,
#  'Missouri': 1,
#  'North': 1,
#  "O'RRight": 1,
#  'Oscar.': 1,
#  'Our': 1,
#  'PACs,': 1,
#  'Pacific': 2,
#  'Pharma': 1,
#  'President': 2,
#  'Purdue': 1,
#  'Putin': 1,
#  'Red': 1,
#  'Republicans,': 1,
#  'Rhonda': 1,
#  'Rights': 1,
#  'River': 1,
#  'Russia,': 1,
#  'Rwanda,': 1,
#  'Santa': 1,
#  'So': 2,
#  'States': 1,
#  'Stoneman': 1,
#  'T': 1,
#  'TI': 1,
#  'TJohn,': 1,
#  'TYes,': 1,
#  'Take': 1,
#  'Tax': 1,
#  'Texas,': 3,
#  'Texas.': 1,
#  'That': 1,
#  "That's": 2,
#  'The': 2,
#  'There': 1,
#  'They': 1,
#  "They're": 1,
#  'This': 1,
#  'Those': 2,
#  'Trump': 2,
#  'U.S.': 1,
#  'United': 1,
#  'Unless': 1,
#  'Valeria': 1,
#  'Vladimir': 1,
#  'Voting': 1,
#  'We': 10,
#  "We're": 2,
#  'When': 1,
#  'You': 1,
#  'a': 30,
#  'ability': 3,
#  'able': 6,
#  'about': 4,
#  'about.': 1,
#  'accept': 1,
#  'access': 2,
#  'account.': 1,
#  'accountability': 1,
#  'achieving': 1,
#  'act': 1,
#  'action': 1,
#  'administration': 1,
#  'administration,': 3,
#  'afford': 2,
#  'against': 1,
#  'age': 1,
#  'agreed.': 1,
#  'agriculture,': 1,
#  'aims': 1,
#  'air': 1,
#  'alienated': 1,
#  'alike,': 1,
#  'all': 3,
#  'alliances': 1,
#  'alliances.': 1,
#  'allies': 2,
#  'already': 1,
#  'already...': 1,
#  'also': 1,
#  'always': 1,
#  'an': 1,
#  'and': 52,
#  'another': 3,
#  'answer': 1,
#  'any': 4,
#  'appreciate': 1,
#  'are': 7,
#  'as': 6,
#  'asking': 1,
#  'assault': 1,
#  'asylum': 2,
#  'at': 7,
#  'attacked': 1,
#  'automatic': 1,
#  'back': 1,
#  'background': 1,
#  'barriers': 1,
#  'bars.': 1,
#  'battlefield': 1,
#  'be': 7,
#  'because': 4,
#  'been': 5,
#  'before': 3,
#  'before,': 1,
#  'beginning': 1,
#  'behind': 1,
#  'belong': 1,
#  'better': 1,
#  'body': 1,
#  'briefly.': 1,
#  'bring': 2,
#  'build': 1,
#  'but': 1,
#  'by': 4,
#  'cages.': 1,
#  'can': 4,
#  "can't": 1,
#  'can,': 1,
#  'capital': 1,
#  'capture': 1,
#  'carbon': 1,
#  'care': 8,
#  'care.': 3,
#  'cared': 2,
#  'case': 1,
#  'cash': 1,
#  'challenge': 1,
#  'challenges': 1,
#  'challenges,': 1,
#  'chance': 1,
#  'change': 2,
#  'change.': 1,
#  'charge': 1,
#  'checks,': 1,
#  'choice': 2,
#  'choose': 1,
#  'citizens': 1,
#  'climate': 2,
#  'close': 1,
#  'closed': 1,
#  'code': 1,
#  'come': 1,
#  'coming': 1,
#  'communities,': 1,
#  'communities.': 2,
#  'community': 2,
#  'complete': 1,
#  'comprehensive': 1,
#  'confront': 2,
#  'connection': 1,
#  'consequences,': 1,
#  'continue.': 1,
#  'conversation': 1,
#  'corporate': 1,
#  'corporations': 2,
#  'cost.': 1,
#  'could': 1,
#  'counties': 1,
#  'countries': 1,
#  'country': 4,
#  'country,': 4,
#  'country.': 3,
#  'county': 1,
#  'crimes,': 1,
#  'criminalize': 1,
#  'criminally': 1,
#  'crisis': 2,
#  'cut': 1,
#  'danger': 1,
#  'dead': 1,
#  'deadliest': 1,
#  'deaths': 1,
#  'debt,': 1,
#  'decisions': 2,
#  'decriminalized': 1,
#  'degrees': 1,
#  'democracies.': 1,
#  'democracy': 4,
#  'dependence': 1,
#  'deportation': 1,
#  'designed': 1,
#  'desperation,': 1,
#  'despite': 1,
#  'detain': 1,
#  'diabetes,': 1,
#  'dictators': 1,
#  'diminished': 1,
#  'do': 3,
#  'do.': 1,
#  'doctor': 1,
#  'does': 1,
#  'does.': 1,
#  "doesn't": 1,
#  "don't": 3,
#  'done,': 1,
#  "driver's": 1,
#  'drug': 1,
#  'each': 2,
#  'economy': 4,
#  'effectively': 2,
#  'efficiently': 1,
#  'effort': 1,
#  'else,': 1,
#  'embraced': 1,
#  'ending': 1,
#  'enough': 1,
#  'enroll': 2,
#  'ensure': 4,
#  'ensuring': 1,
#  'environmental': 1,
#  'every': 4,
#  'everybody': 3,
#  'everybody.': 1,
#  'everyone.': 3,
#  'everywhere,': 1,
#  'existential': 1,
#  'expense': 2,
#  'explain': 1,
#  'face': 3,
#  'face.': 1,
#  'fact,': 2,
#  'fair': 1,
#  'families': 1,
#  'family': 3,
#  'family,': 1,
#  'farmers': 3,
#  'farms': 1,
#  'father,': 1,
#  'favored': 1,
#  'favors': 1,
#  'fear': 1,
#  'fellow': 1,
#  'flag': 1,
#  'fleeing': 5,
#  'flooded': 1,
#  'flooded.': 1,
#  'follow': 2,
#  'for': 12,
#  'for...': 1,
#  'foreign': 2,
#  'forever': 1,
#  'forward.': 1,
#  'fossil': 1,
#  'found': 1,
#  'fraction': 1,
#  'free': 2,
#  'friend,': 1,
#  'friends': 1,
#  'friends.': 1,
#  'friendships': 1,
#  'from': 5,
#  'front': 1,
#  'front,': 1,
#  'fuels,': 1,
#  'full': 1,
#  'fund': 1,
#  'fundamental': 1,
#  'generate': 1,
#  'genocide': 3,
#  'gerrymandering,': 1,
#  'get': 3,
#  'getting': 1,
#  'glaucoma,': 1,
#  'go': 1,
#  'goal': 1,
#  'goal.': 1,
#  'going': 7,
#  'got': 2,
#  'great': 1,
#  'guaranteed,': 1,
#  'gun-owners': 1,
#  'had': 4,
#  'half': 1,
#  'has': 8,
#  'have': 10,
#  'he': 6,
#  "he'd": 1,
#  "he'll": 1,
#  "he's": 1,
#  'health': 7,
#  'help': 1,
#  'helped': 1,
#  'her': 4,
#  'here': 2,
#  'high': 1,
#  'high-quality,': 1,
#  'his': 1,
#  'historic': 1,
#  'hold': 1,
#  'home': 1,
#  'how': 3,
#  'if': 5,
#  'image,': 1,
#  'immigration': 2,
#  'implement': 1,
#  'impunity': 1,
#  'in': 40,
#  'including': 1,
#  'income.': 1,
#  'independents': 1,
#  'inequality.': 1,
#  'insufficiently': 1,
#  'insured,': 1,
#  'interests': 1,
#  'into': 2,
#  'introduce': 1,
#  'invaded': 1,
#  'invest': 1,
#  'invitation': 1,
#  'is': 11,
#  "isn't.": 1,
#  'issue.': 1,
#  'it': 6,
#  "it's": 6,
#  'it.': 2,
#  'jail': 1,
#  'jail.': 1,
#  'journey': 1,
#  'just': 3,
#  'justice,': 1,
#  'keep': 4,
#  'kids': 1,
#  'kill': 1,
#  'kind': 3,
#  'know': 3,
#  'lakes,': 1,
#  'largest': 2,
#  'late.': 2,
#  'laws': 3,
#  'laws,': 1,
#  'laws.': 3,
#  'learned': 1,
#  'led': 2,
#  'legalized': 1,
#  'legislation': 1,
#  'less': 1,
#  'life,': 1,
#  'life.': 1,
#  'like': 1,
#  'lines': 1,
#  'listen': 1,
#  'listening': 1,
#  'live': 3,
#  'lives.': 1,
#  'long-term': 1,
#  'looking': 1,
#  'loophole.': 1,
#  'lost': 1,
#  'made': 1,
#  'make': 10,
#  'makes': 2,
#  'making': 3,
#  'malfeasance': 1,
#  'man,': 1,
#  'management': 1,
#  'marijuana,': 1,
#  'markets': 1,
#  'match': 1,
#  'me': 2,
#  'mean': 1,
#  'meaningly': 1,
#  'meet': 1,
#  'member': 2,
#  'mental': 2,
#  'met': 1,
#  'mile': 1,
#  'million': 1,
#  'mobilize': 1,
#  'more': 4,
#  'mother': 1,
#  'much': 2,
#  'must': 1,
#  'my': 1,
#  'named': 1,
#  'need': 1,
#  'negotiated': 1,
#  'never': 1,
#  'new': 2,
#  'next': 1,
#  'night': 1,
#  'no': 5,
#  'non-gun-owners': 1,
#  'nonviolent': 1,
#  'not': 8,
#  'now': 1,
#  'now,': 2,
#  'now...': 1,
#  'of': 32,
#  'offered': 1,
#  'old,': 1,
#  'on': 7,
#  'once': 1,
#  'one': 2,
#  'opioid': 1,
#  'or': 4,
#  'ordinary': 1,
#  'our': 26,
#  'ourselves': 1,
#  'out': 1,
#  'outcomes.': 1,
#  'outside': 1,
#  'over': 1,
#  'overdose': 1,
#  'own': 4,
#  'part': 1,
#  'partners': 1,
#  'partnerships': 1,
#  'pass.': 1,
#  'pay': 4,
#  'paying': 1,
#  'people': 3,
#  'people,': 1,
#  'percent.': 1,
#  'persecution...': 1,
#  'piles': 1,
#  'place': 1,
#  'places': 1,
#  'plan': 2,
#  'planet': 2,
#  'planet.': 1,
#  'policy': 1,
#  'policy.': 1,
#  'population': 1,
#  'poses': 1,
#  'possession': 1,
#  'possible': 1,
#  'possible.': 2,
#  'potential': 1,
#  'potential.': 1,
#  'power': 1,
#  'premiums,': 1,
#  'prescriptions': 1,
#  'presents': 1,
#  'preserve': 1,
#  'president,': 1,
#  'preventing': 1,
#  'price,': 1,
#  'primary': 1,
#  'priorities': 1,
#  'prison': 1,
#  'program': 1,
#  'programs': 1,
#  'promise': 1,
#  'prosecute': 1,
#  'provide.': 1,
#  'provider': 1,
#  'provider,': 1,
#  'provider.': 1,
#  'put': 2,
#  'question.': 1,
#  'quickly': 1,
#  'ranchers': 1,
#  'rate': 2,
#  'reason': 1,
#  'record': 1,
#  'refer,': 1,
#  'referenced': 1,
#  'reflected': 1,
#  'refuge': 1,
#  'regional': 1,
#  'registration': 1,
#  'renewable': 1,
#  'resiliency': 1,
#  'respect.': 1,
#  'respond': 1,
#  'returned': 1,
#  'reunite': 1,
#  'revenues...': 1,
#  'revived': 1,
#  'rewrite': 2,
#  'rid': 1,
#  'rigged': 1,
#  'right': 1,
#  'right.': 1,
#  'right...': 1,
#  'sales': 1,
#  'same': 1,
#  'same-day': 1,
#  'same.': 1,
#  'save': 1,
#  'saw': 1,
#  'says': 1,
#  'school': 1,
#  'seat,': 1,
#  'see': 1,
#  'seeing': 1,
#  'seeking': 1,
#  'separated': 1,
#  'services': 2,
#  'shared': 1,
#  'shooting,': 2,
#  'should': 2,
#  'single': 2,
#  'sitting': 1,
#  'small': 1,
#  'so': 3,
#  'soil,': 1,
#  'solutions': 2,
#  'someone': 2,
#  'spare': 1,
#  'stakeholders': 1,
#  'standing': 1,
#  'states': 1,
#  'stop': 1,
#  'stopped': 1,
#  'strengthen': 1,
#  'stronger.': 1,
#  'strongmen': 1,
#  'student': 1,
#  'students': 2,
#  'support': 1,
#  'sure': 6,
#  'sure...': 2,
#  'surely': 1,
#  'survived': 2,
#  'sustainable': 1,
#  'system': 2,
#  'take': 1,
#  'talked': 2,
#  'talking': 2,
#  'tax': 5,
#  'tell': 1,
#  'than': 1,
#  'that': 46,
#  'that,': 1,
#  'the': 52,
#  'the...': 1,
#  'their': 3,
#  'them': 6,
#  'them.': 1,
#  'themselves': 1,
#  'then': 3,
#  'there': 1,
#  "there's": 2,
#  'they': 10,
#  "they're": 2,
#  "they've": 2,
#  'think': 3,
#  'this': 20,
#  'this.': 1,
#  'those': 11,
#  'threat': 1,
#  'throughout': 1,
#  'time': 2,
#  'to': 62,
#  'to...': 1,
#  'today.': 3,
#  'together': 1,
#  'together.': 1,
#  'told': 4,
#  'too': 3,
#  'town': 1,
#  'trade': 1,
#  'traveling': 1,
#  'treated': 1,
#  'treatment': 1,
#  'trillion': 2,
#  'turn': 1,
#  'under': 2,
#  'undertaken': 1,
#  'underwater': 1,
#  'unfortunately,': 1,
#  'uninsured,': 1,
#  'union': 1,
#  'united': 1,
#  'universal': 2,
#  'untreated': 1,
#  'up': 3,
#  'us': 3,
#  'values': 2,
#  'very': 3,
#  'victim': 1,
#  'victims': 1,
#  'violence': 1,
#  'violence,': 1,
#  'visit,': 1,
#  'voice': 1,
#  'voter': 1,
#  'voters,': 1,
#  'walls.': 1,
#  'want': 4,
#  'war': 2,
#  'warming': 1,
#  'was': 3,
#  'we': 23,
#  "we're": 5,
#  "we've": 1,
#  'weaker': 1,
#  'wealth': 1,
#  'wealthiest': 1,
#  'wealthiest.': 1,
#  'weapons': 2,
#  'well': 1,
#  'were': 5,
#  'what': 5,
#  'when': 1,
#  'where': 1,
#  'whether': 1,
#  'which': 1,
#  'while': 1,
#  'who': 9,
#  "who've": 1,
#  'whom': 1,
#  'why': 1,
#  'why.': 1,
#  'will': 6,
#  'with': 5,
#  'woman': 1,
#  'work': 3,
#  'work,': 1,
#  'working,': 1,
#  'works': 1,
#  'world': 1,
#  'would': 13,
#  'years': 1,
#  'years.': 1,
#  'yes,': 1,
#  'yet': 1,
#  'you': 16,
#  "you're": 7,
#  "you've": 1,
#  'young': 3,
#  'your': 3}

# %%
word_histogram2 = {k: v for k, v in word_histogram.items() if v > 3}

# %%
import plotly
from plotly.offline import iplot, init_notebook_mode
from plotly import tools
import plotly.graph_objs as go
init_notebook_mode(connected=True)
 
trace = {'type': 'bar', 'x': list(unique_words), 'y': list(word_histogram2.values())}
 
plotly.offline.iplot({'data': [trace]})
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="484bb660-859c-4831-bf82-3c25ce71de7c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("484bb660-859c-4831-bf82-3c25ce71de7c")) {
#                     Plotly.newPlot(
#                         '484bb660-859c-4831-bf82-3c25ce71de7c',
#                         [{"type": "bar", "uid": "74c0c20e-1e20-4791-b9e6-7aa57942a911", "x": ["", "universal", "chance", "people", "2", "my", "doesn't", "achieving", "victim", "insured,", "your", "seat,", "full", "enough", "insufficiently", "Dreamers", "charge", "complete", "stop", "guaranteed,", "places", "generate", "better", "action", "see", "support", "right...", "countries", "driver's", "glaucoma,", "Celsius,", "saw", "world", "enroll", "effort", "C...", "D...", "says", "economy", "ranchers", "mental", "one", "loophole.", "Junction", "aims", "premiums,", "beginning", "know", "deadliest", "alliances", "planet.", "always", "survived", "must", "hold", "put", "fraction", "than", "corporations", "revenues...", "voice", "values", "states", "power", "you're", "less", "28", "cared", "capture", "Red", "ensuring", "accept", "potential", "justice,", "dictators", "that", "rigged", "you've", "embraced", "ourselves", "mile", "own", "would", "40.", "administration,", "consequences,", "under", "population", "part", "briefly.", "everywhere,", "all", "provide.", "(CROSSTALK)", "tell", "age", "immigration", "Take", "walls.", "tax", "families", "alliances.", "coming", "because", "Rights", "persecution...", "promise", "someone", "then", "policy.", "Her", "where", "mean", "account.", "Russia,", "don't", "be", "Our", "closed", "This", "trillion", "A", "DOur", "stakeholders", "fact,", "works", "record", "should", "everybody", "wealthiest", "system", "now", "can't", "home", "allies", "farmers", "American", "preserve", "he", "nonviolent", "small", "ordinary", "farms", "listen", "make", "resiliency", "Republicans,", "every", "it", "Miami,", "Those", "a", "bring", "working,", "soil,", "it's", "I'll", "DThat's", "legislation", "woman", "refer,", "time", "So", "alike,", "negotiated", "do.", "shooting,", "including", "U.S.", "could", "planet", "largest", "North", "done,", "Unless", "I", "citizens", "Central", "before", "union", "diabetes,", "capital", "us", "close", "answer", "ensure", "go", "was", "2.3", "work", "we're", "kind", "had", "belong", "wealth", "isn't.", "despite", "presents", "kids", "out", "Marjory", "CHere's", "makes", "jail.", "We're", "talked", "threat", "percent.", "genocide", "code", "corporate", "family,", "gerrymandering,", "fleeing", "free", "or", "which", "that,", "talking", "very", "have", "criminalize", "else,", "single", "automatic", "they", "undertaken", "student", "can,", "now...", "her", "access", "Santa", "United", "potential.", "detain", "price,", "sustainable", "you", "throughout", "Medicare.", "Marcel,", "Oscar.", "meaningly", "Korea", "follow", "seeking", "never", "We", "our", "students", "no", "GThat's", "he'd", "existential", "now,", "TI", "invest", "country.", "laws", "Act", "when", "late.", "outcomes.", "paying", "favors", "possible", "got", "from", "agriculture,", "high-quality,", "well", "malfeasance", "front", "change.", "with", "communities,", "goal", "asylum", "each", "there's", "programs", "overdose", "laws.", "cages.", "shared", "want", "more", "and", "2,000", "challenges", "That", "goal.", "much", "spare", "Democrats", "2016,", "environmental", "into", "come", "GI", "air", "sales", "afford", "services", "TJohn,", "provider", "surely", "invitation", "not", "has", "They", "victims", "DLet", "who've", "for...", "lines", "do", "prosecute", "meet", "PACs,", "rid", "same", "When", "income.", "told", "counties", "reason", "Florida,", "case", "offered", "up", "$2", "build", "CWe", "themselves", "the...", "Laredo,", "health", "Rhonda", "they're", "help", "decriminalized", "Junction,", "friends", "at", "background", "cost.", "--", "policy", "danger", "care.", "Stoneman", "old,", "long-term", "primary", "high", "markets", "while", "violence", "You", "before,", "renewable", "outside", "comprehensive", "next", "country", "found", "wealthiest.", "keep", "fair", "Tax", "accountability", "helped", "foreign", "trade", "everybody.", "challenge", "does.", "The", "sure...", "regional", "image,", "those", "Voting", "uninsured," ...
#                         {},

# %%
df_hist = ''
df_hist = pd.DataFrame.from_dict(word_histogram,orient='index')
df_hist.columns=['freq']
df_hist
# Out:
#                 freq
#                   24
# universal          2
# chance             1
# people             3
# 2                  1
# my                 1
# doesn't            1
# achieving          1
# victim             1
# insured,           1
# your               3
# seat,              1
# full               1
# enough             1
# insufficiently     1
# Dreamers           1
# charge             1
# complete           1
# stop               1
# guaranteed,        1
# places             1
# generate           1
# better             1
# action             1
# see                1
# support            1
# right...           1
# countries          1
# driver's           1
# glaucoma,          1
# ...              ...
# president,         1
# back               1
# CBut               1
# crimes,            1
# Vladimir           1
# an                 1
# member             2
# flooded.           1
# quickly            1
# $5                 1
# CIf                1
# favored            1
# provider,          1
# face.              1
# prison             1
# it.                2
# explain            1
# registration       1
# independents       1
# fuels,             1
# violence,          1
# we've              1
# united             1
# been               5
# pass.              1
# community          2
# we                23
# rate               2
# able               6
# continue.          1
#
# [695 rows x 1 columns]

# %%
# print(listofTuples)

# %%
# dict((x, y) for x, y in listofTuples)

# %%
# dfObj = pd.DataFrame(listofTuples, columns=['word', 'freq'])

# %%
# dfObj = dfObj.head(50)

# %%
# trace = {'type': 'bar', 'x': dfObj['word'], 'y': dfObj['freq']}
 
# plotly.offline.iplot({'data': [trace]})

# %%
# articles = ['a','an','and','the']

# %% [markdown]
# **Another way of tokenization**

# %%
import nltk
nltk.download()
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
  
example_sent = "This is a sample sentence, showing off the stop words filtration."
  
stop_words = set(stopwords.words('english')) 
  
word_tokens = word_tokenize(example_sent) 
  
filtered_sentence = [w for w in word_tokens if not w in stop_words] 
  
filtered_sentence = [] 
  
for w in word_tokens: 
    if w not in stop_words: 
        filtered_sentence.append(w) 

print(word_tokens) 
print(filtered_sentence)
